# %%
import matplotlib.pyplot as plt
import glob 
import numpy as np

I = []
for im in glob.glob("Data/PC*"):
    i = plt.imread(im)
    print(im)
    if len(i.shape) > 2:
        I.append(i[:,:,0])

    else:
        print(im)
        I.append(i)
# Out:
# Data/PC_PI_Col0_1.tif
# Data/PC_PI_Col0_2.tif
# Data/PC_PI_Col0_3.tif
# Data/PC_PI_Col0_4.tif
# Data/PC_PI_Col0_5.tif
# Data/PC_PI_Col0_6.tif
# Data/PC_PI_Col0_7.tif
# Data/PC_PI_Col0_7.tif
# Data/PC_PI_Col0_8.tif
# Data/PC_PI_Col0_8.tif

# %%
[print(im.shape) for im in I]
# Out:
# (1024, 1024)
# (1024, 1024)
# (1024, 1024)
# (1024, 1024)
# (1024, 1024)
# (1024, 1024)
# (1024, 1024)
# (1024, 1024)
# [None, None, None, None, None, None, None, None]

# %%
plt.figure(figsize=(20,20))
#plt.imshow(I[-7] != 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/nikita/Documents/ded/new_dreams_ltd.ipynb Cell 3' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/nikita/Documents/ded/new_dreams_ltd.ipynb#ch0000002?line=0'>1</a> plt.figure(figsize=(20,20))
#       <a href='vscode-notebook-cell:/home/nikita/Documents/ded/new_dreams_ltd.ipynb#ch0000002?line=1'>2</a> plt.imshow(I[-7] != 0)
# ----> <a href='vscode-notebook-cell:/home/nikita/Documents/ded/new_dreams_ltd.ipynb#ch0000002?line=2'>3</a> plt.contourf(I[0][0], I[0][1])
#
# File ~/.virtualenvs/audio/lib64/python3.9/site-packages/matplotlib/pyplot.py:2482, in contourf(data, *args, **kwargs)
#    <a href='file:///home/nikita/.virtualenvs/audio/lib64/python3.9/site-packages/matplotlib/pyplot.py?line=2479'>2480</a> @_copy_docstring_and_deprecators(Axes.contourf)
# ...

# %%
plt.hist(I[-1].flatten(), bins=30)
# Out:
# (array([8.22342e+05, 5.89000e+02, 1.10097e+05, 7.20000e+01, 3.20000e+01,
#         9.56820e+04, 9.00000e+00, 9.54600e+03, 0.00000e+00, 1.00000e+00,
#         8.53300e+03, 0.00000e+00, 7.60000e+02, 0.00000e+00, 0.00000e+00,
#         7.87000e+02, 0.00000e+00, 5.50000e+01, 0.00000e+00, 0.00000e+00,
#         5.80000e+01, 0.00000e+00, 4.00000e+00, 0.00000e+00, 0.00000e+00,
#         8.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([ 0. ,  1.6,  3.2,  4.8,  6.4,  8. ,  9.6, 11.2, 12.8, 14.4, 16. ,
#         17.6, 19.2, 20.8, 22.4, 24. , 25.6, 27.2, 28.8, 30.4, 32. , 33.6,
#         35.2, 36.8, 38.4, 40. , 41.6, 43.2, 44.8, 46.4, 48. ]),
#  <BarContainer object of 30 artists>)

# %%
np.unique(I[-1].flatten())
# Out:
# array([ 0,  2,  3,  4,  5,  6,  7,  8, 10, 11, 12, 15, 16, 20, 24, 28, 32,
#        36, 40, 48], dtype=uint8)

# %%
# Out:
# array([0, 0, 0, ..., 4, 0, 0], dtype=uint8)
